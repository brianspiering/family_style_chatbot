# %%
import pandas as pd
import numpy as np
np.random.seed(1234)

# %%
users = ['Brian', 'David', 'Eugene', 'Jon', 'Marvin']
cuisines = ['China', 'France', 'India', 'Indonesia', 'Italy', 'Japan', 
            'Mexico', 'Singapore', 'Thailand', 'Vietnam']
#dishes = ['Burger', 'Noodles', 'Pizza']
possible_cuisine_or_dish_rating = np.arange(0.5, 5.5, 0.5)


def generate_ratings(length, possible_scores=np.arange(0.5, 5.5, 0.5)):
    return np.random.choice(possible_scores, length)

def dish_scorer(number_of_people, number_of_dishes):
    return generate_ratings((number_of_people, number_of_dishes))

# %%
cuisine_dish_list = {"Singapore": ['Sesame Oil Chicken Wings', 'Singapore Satay', 'Singapore Chili Crabs',
 'Singapore Noodle Curry Shrimp', 'Singapore Sling Cocktail', 'Singapore Laksa'],
 
 'Mexico': ['Great Chicken Taquitos', 'Double Chili cheese Dip', 'Grilled Fish Tacos', 
'Chili Rellenos', 'Albondigas', 'Vegetarian Tortilla Soup'],
 
 'Indonesia': ['Indonesian Banana Fritters', 'Indonesia Satay', 'Indonesian Spiced Rice', 
               'Indonesian Fried Noodles', 'Indonesian Beef Rendang', 'Oxtail soup'],
                     
 'France': ['Peach and Goat Cheese Tartine', 'Creme brulee', 'Crepe Suzette', 'Ratatouille',
            'French Onion Soup', 'French Beef Stew'],
                     
  'China': ['Chinese Tea Leaf Eggs', 'Seseame Oil Chicken Wings', 'Chinese Mabo Tofu',
             "General Tsao's Chicken", 'Chinese Sizzling Rice Soup', 'Chinese Corn Soup'],
                     
 'Vietnam': ['Vietnamese Fresh Spring Rolls', 'Vietnamese Salad Rolls', 'Vietnamese Chicken Salad', 
             'Vietnamese Aromatic Lamb Chops', 'Vietnamese Beef Pho', 'Vietnamese Style Vegetarian Curry Soup'],
                     
 'Japan': ['Japanese-Style Grilled Mushrooms', 'Tofu Hiyayakko', 'Crispy Shrimp Tempura', 
           'Miso Salmon', 'Dashi Stock', 'Beef Sukiyaki'], 

                     
 'India': ['Crispy Vegetables Pakoras', 'Green Chutney', 'Indian Pizza', 'Curried Chickpeas', 
           'Indian Chai', 'Mango-Mint Lassi'],

 'Thailand': ['Fried Chicken Wings', 'Fried Tofu with Peanut Dipping Sauce', 'Barbeque Pork on Rice',
              'Beef Stew Recipe', 'Thai Ginger Soup', 'Thai Hout and Sour Soup'],

 'Italy': ['Caprese Appetizer', 'Prosciutto Cups', 'Shrimp Scampi with Pasta', 'Pork Chops Italiano',
        'Italian Halibut Chwoder', 'Creamy Italian White Bean Soup'],
                     
 'Pizza': ['Berry, Arugula and Prosciutto Pizza', 'Macaroni And Cheese Pizza', 
           'Butternut Squash and Crispy Sage Pizza', 'Buffalo Chicken Pizza Sticks',
          'Cantaloupe And Sweet Ricotta Pizza', 'Hummus And Grilled Zucchini Pizzas']
            
}

# %%
user_cuisine_rating = pd.DataFrame({'Users': users})

for cuisine in cuisines:
    user_cuisine_rating[cuisine] = None

user_cuisine_rating.ix[:, 1:] = generate_ratings(user_cuisine_rating.shape - np.array([0, 1]))
user_cuisine_rating
# Out:
#     Users China France India Indonesia Italy Japan Mexico Singapore Thailand  \
# 0   Brian     2    3.5     3       2.5   4.5     5      1         4        5
# 1   David   4.5    0.5     3       0.5     5   3.5    1.5       0.5        3
# 2  Eugene   3.5      2     4       0.5     5   0.5      2       1.5        2
# 3     Jon     2      1     2         4     1     4    2.5       0.5        3
# 4  Marvin     3      5     5       2.5   0.5     5    4.5       4.5      3.5
#
#   Vietnam
# 0     3.5
# 1     1.5
# 2       1
# 3       1
# 4     4.5

# %%
cuisine_user_dish_tables = {}
for cuisine in cuisine_dish_list:
    temp = pd.DataFrame({'Users':users})
    for dish in cuisine_dish_list[cuisine]:
        temp[dish] = None
        temp.ix[:, 1:] = generate_ratings(temp.shape - np.array([0, 1]))
    cuisine_user_dish_tables[cuisine] = temp

# %%
for table in cuisine_user_dish_tables:
    print table
    print cuisine_user_dish_tables[table]
    print
# Out:
# Italy
#     Users Caprese Appetizer Prosciutto Cups Shrimp Scampi with Pasta  \
# 0   Brian                 1               5                      1.5
# 1   David               1.5               3                        3
# 2  Eugene               2.5             0.5                      0.5
# 3     Jon                 5               1                        5
# 4  Marvin                 2             2.5                      2.5
#
#   Pork Chops Italiano Italian Halibut Chwoder Creamy Italian White Bean Soup
# 0                   4                     2.5                              2
# 1                   1                     0.5                            4.5
# 2                   1                     0.5                              2
# 3                   2                       4                              5
# 4                   1                       1                            3.5
#
# Singapore
#     Users Sesame Oil Chicken Wings Singapore Satay Singapore Chili Crabs  \
# 0   Brian                        5               3                     2
# 1   David                        1               1                   4.5
# 2  Eugene                      2.5             1.5                   2.5
# 3     Jon                      1.5             3.5                     1
# 4  Marvin                        2               5                   2.5
#
#   Singapore Noodle Curry Shrimp Singapore Sling Cocktail Singapore Laksa
# 0                             4                        1             0.5
# 1                             2                        3             2.5
# 2                             3                      3.5             2.5
# 3                             4                      3.5             1.5
# 4                             1                      2.5               1
#
# Indonesia
#     Users Indonesian Banana Fritters Indonesia Satay Indonesian Spiced Rice  \
# 0   Brian                        2.5               1                      1
# 1   David                        2.5             1.5                      1
# 2  Eugene                        0.5             1.5                      1
# 3     Jon                        4.5             4.5                      4
# 4  Marvin                        0.5             3.5                    3.5
#
#   Indonesian Fried Noodles Indonesian Beef Rendang Oxtail soup
# 0                        1                     1.5           2
# 1                        5                     2.5         0.5
# 2                      1.5                       3           5
# 3                        3                       4         0.5
# 4                        1                       5         2.5
#
# India
#     Users Crispy Vegetables Pakoras Green Chutney Indian Pizza  \
# 0   Brian                       2.5             4          2.5
# 1   David                       2.5             4            4
# 2  Eugene                       3.5             3            3
# 3     Jon                       0.5           4.5            2
# 4  Marvin                       2.5             4          3.5
#
#   Curried Chickpeas Indian Chai Mango-Mint Lassi
# 0                 2         1.5              4.5
# 1               0.5           1              2.5
# 2               0.5           3              1.5
# 3                 3           4              4.5
# 4                 4           4              1.5
#
# France
#     Users Peach and Goat Cheese Tartine Creme brulee Crepe Suzette  \
# 0   Brian                             2          3.5           3.5
# 1   David                             5            2           4.5
# 2  Eugene                             2            1             2
# 3     Jon                             2            3           1.5
# 4  Marvin                           2.5            1           0.5
#
#   Ratatouille French Onion Soup French Beef Stew
# 0         1.5               1.5              2.5
# 1           4                 3                1
# 2         0.5               1.5              0.5
# 3         3.5               3.5              3.5
# 4           4               2.5                1
#
# Mexico
#     Users Great Chicken Taquitos Double Chili cheese Dip Grilled Fish Tacos  \
# 0   Brian                      1                     0.5                3.5
# 1   David                      1                     4.5                1.5
# 2  Eugene                      5                     0.5                3.5
# 3     Jon                      5                     1.5                1.5
# 4  Marvin                      3                     0.5                  5
#
#   Chili Rellenos Albondigas Vegetarian Tortilla Soup
# 0              2          2                      2.5
# 1            4.5        0.5                        2
# 2            3.5          4                        4
# 3              1        0.5                        5
# 4              4          3                        2
#
# Vietnam
#     Users Vietnamese Fresh Spring Rolls Vietnamese Salad Rolls  \
# 0   Brian                             2                      4
# 1   David                           1.5                      2
# 2  Eugene                             3                    1.5
# 3     Jon                             5                      4
# 4  Marvin                             4                      3
#
#   Vietnamese Chicken Salad Vietnamese Aromatic Lamb Chops Vietnamese Beef Pho  \
# 0                      1.5                            4.5                   2
# 1                      2.5                              1                 3.5
# 2                      2.5                            1.5                   1
# 3                        5                              4                 1.5
# 4                      4.5                              3                 0.5
#
#   Vietnamese Style Vegetarian Curry Soup
# 0                                    1.5
# 1                                      2
# 2                                      2
# 3                                      3
# 4                                    2.5
#
# China
#     Users Chinese Tea Leaf Eggs Seseame Oil Chicken Wings Chinese Mabo Tofu  \
# 0   Brian                     3                       3.5               3.5
# 1   David                     1                       0.5                 3
# 2  Eugene                     2                         1                 3
# 3     Jon                   0.5                         3               2.5
# 4  Marvin                     4                         5               3.5
#
#   General Tsao's Chicken Chinese Sizzling Rice Soup Chinese Corn Soup
# 0                    3.5                          4                 1
# 1                      5                        1.5                 1
# 2                    0.5                          2               1.5
# 3                    4.5                          2               0.5
# 4                      2                        2.5                 2
#
# Japan
#     Users Japanese-Style Grilled Mushrooms Tofu Hiyayakko  \
# 0   Brian                                2              1
# 1   David                              0.5              2
# 2  Eugene                              0.5              4
# 3     Jon                              4.5            4.5
# 4  Marvin                              4.5            3.5
#
#   Crispy Shrimp Tempura Miso Salmon Dashi Stock Beef Sukiyaki
# 0                     2         3.5           2             3
# 1                     3           1           2           4.5
# 2                     2           2         1.5           2.5
# 3                   0.5           4         4.5           0.5
# 4                   2.5         1.5           2           0.5
#
# Thailand
#     Users Fried Chicken Wings Fried Tofu with Peanut Dipping Sauce  \
# 0   Brian                 4.5                                    1
# 1   David                 1.5                                  2.5
# 2  Eugene                 1.5                                  3.5
# 3     Jon                 3.5                                  3.5
# 4  Marvin                   3                                    4
#
#   Barbeque Pork on Rice Beef Stew Recipe Thai Ginger Soup  \
# 0                     4              2.5                1
# 1                     2                2                5
# 2                   0.5                3              2.5
# 3                     2              4.5              4.5
# 4                     5                5              0.5
#
#   Thai Hout and Sour Soup
# 0                       5
# 1                     2.5
# 2                     3.5
# 3                     4.5
# 4                       4
#
# Pizza
#     Users Berry, Arugula and Prosciutto Pizza Macaroni And Cheese Pizza  \
# 0   Brian                                   5                       4.5
# 1   David                                 1.5                         2
# 2  Eugene                                   2                       2.5
# 3     Jon                                 1.5                       4.5
# 4  Marvin                                   3                         5
#
#   Butternut Squash and Crispy Sage Pizza Buffalo Chicken Pizza Sticks  \
# 0                                      3                            5
# 1                                    0.5                            5
# 2                                      3                          0.5
# 3                                      3                            2
# 4                                    0.5                          3.5
#
#   Cantaloupe And Sweet Ricotta Pizza Hummus And Grilled Zucchini Pizzas
# 0                                  2                                4.5
# 1                                0.5                                2.5
# 2                                1.5                                  4
# 3                                  3                                0.5
# 4                                  4                                1.5

# %%
user_cuisine_rating.to_json('user_by_cuisine_ratings.json')

import cPickle as pkl

with open('user_by_cuisine_by_dish_ratings.pkl', 'wb') as file:
    pkl.dump(cuisine_user_dish_tables, file)

# %%
# unused code
"""user_dish_rating = pd.DataFrame({'Users': users})

for dish in dishes:
    user_dish_rating[dish] = None

user_dish_rating.ix[:, 1:] = generate_ratings(user_dish_rating.shape - np.array([0, 1]))
user_dish_rating
"""

#temp == some_tables

#dish_cuisine_rating = cusine_coef * cuisine_rating + dish_coef * dish_rating
# Out:
# "user_dish_rating = pd.DataFrame({'Users': users})\n\nfor dish in dishes:\n    user_dish_rating[dish] = None\n\nuser_dish_rating.ix[:, 1:] = generate_ratings(user_dish_rating.shape - np.array([0, 1]))\nuser_dish_rating\n"
